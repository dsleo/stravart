# %% [markdown]
# # Starter Notebook
#
# Just to get a feel of the package API.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## From Image Contour to Bicycle Route on a Map

# %%
from stravart.utils import *
from stravart.polygone import *
from stravart.operations import *
from stravart.visualization import *

# %%
cat_face_coordinates = [
    # Start from the bottom of the left ear
    (-4, 7), (-3.5, 8), (-3, 9), (-2.5, 10), (-2, 10.5), (-1.5, 11), (-1, 11.5), (-0.5, 11.75), (0, 12),
    # Top of head to the right ear
    (0.5, 11.75), (1, 11.5), (1.5, 11), (2, 10.5), (2.5, 10), (3, 9), (3.5, 8), (4, 7),
    # Right side of the face
    (3.5, 6), (3, 5), (2.5, 4), (2, 3), (1.5, 2), (1, 1), (0.5, 0), (0, -1),
    # Bottom of the face and left side
    (-0.5, 0), (-1, 1), (-1.5, 2), (-2, 3), (-2.5, 4), (-3, 5), (-3.5, 6), (-4, 7),
    # Adding whiskers on the left side
    (-4.5, 6.5), (-5, 6), (-5.5, 5.5), (-6, 5), (-5.5, 4.5), (-5, 4), (-4.5, 3.5), (-4, 3),
    # Returning to the bottom of the left ear
    (-3.5, 3.5), (-3, 4), (-2.5, 4.5), (-2, 5), (-1.5, 5.5), (-1, 6), (-0.5, 6.5), (0, 7),
    # Crossing to the right side
    (0.5, 6.5), (1, 6), (1.5, 5.5), (2, 5), (2.5, 4.5), (3, 4), (3.5, 3.5), (4, 3),
    # Adding whiskers on the right side
    (4.5, 3.5), (5, 4), (5.5, 4.5), (6, 5), (5.5, 5.5), (5, 6), (4.5, 6.5), (4, 7),
    # Completing the loop back to the start
    (3.5, 7.5), (3, 8), (2.5, 8.5), (2, 9), (1.5, 9.5), (1, 10), (0.5, 10.5), (0, 11),
    (-0.5, 10.5), (-1, 10), (-1.5, 9.5), (-2, 9), (-2.5, 8.5), (-3, 8), (-3.5, 7.5), (-4, 7)
]

# Simplify the cat face coordinates
simplified_cat_face = simplify_coordinates(cat_face_coordinates)
#print("Simplified Coordinates:", simplified_cat_face)

# Extract x and y coordinates
x_coords, y_coords = zip(*cat_face_coordinates)
x2_coords, y2_coords = zip(*simplified_cat_face)

# Plotting
plt.figure(figsize=(4, 4))
#plt.plot(y_coords, x_coords, marker='o')
for i, (x_coord, y_coord) in enumerate(simplified_cat_face):
    plt.text(y_coord, x_coord, str(i), fontsize=9, ha='right')

plt.plot(y2_coords, x2_coords, marker='x')

plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.grid(True)
plt.axis('equal')  # Ensure the aspect ratio is equal to maintain the shape
plt.show()

# %%
contour = simplified_cat_face
map_center = (48.8675, 2.3638)  
radius = 0.01  # Example radius in degrees (approx 1 km)

poly =  Polygon.from_list(coordinates_list=contour, system="cartesian")
projection = Projection(center=map_center, radius=radius, map_type="GPS")
gps_poly = projection.apply(poly)
bicycle_contour = gps_poly.get_nearest_bicycle_road_points(dist=2000)

actual_bicycle_contour, path_mapping = Route(bicycle_contour).fill_paths_between_points()
final_contour = actual_bicycle_contour.filter_close_points()

#plot_route(map_center=map_center, route=bicycle_contour)
plot_route(map_center=map_center, route=final_contour)
# Out:
# [(48.8646241, 2.3640156), (48.8657293, 2.3662336), (48.8666509, 2.3673468), (48.8675419, 2.3679208), (48.8687437, 2.3673318), (48.8704561, 2.3663507), (48.8715703, 2.3635654), (48.8675036, 2.355827), (48.8646241, 2.3640156), (48.8627724, 2.3610521), (48.8647062, 2.3597995), (48.868106, 2.3636766), (48.8715027, 2.3603436), (48.8731067, 2.3614285), (48.8684079, 2.3662262), (48.8646241, 2.3640156)]
# (48.8646241, 2.3640156) (48.8657293, 2.3662336)
# best [(48.8646, 2.364), (48.8647, 2.3645), (48.8652, 2.3653), (48.8645, 2.3661), (48.8647, 2.3659), (48.8657, 2.3662)]
# -----------
# (48.8657293, 2.3662336) (48.8666509, 2.3673468)
# best [(48.8657, 2.3662), (48.8657, 2.3663), (48.8662, 2.3663), (48.8661, 2.3665), (48.8667, 2.3673)]
# -----------
# (48.8666509, 2.3673468) (48.8675419, 2.3679208)
# best [(48.8667, 2.3673), (48.8667, 2.3674), (48.8675, 2.3679)]
# -----------
# (48.8675419, 2.3679208) (48.8687437, 2.3673318)
# best [(48.8675, 2.3679), (48.8676, 2.368), (48.8687, 2.3673)]
# -----------
# (48.8687437, 2.3673318) (48.8704561, 2.3663507)
# best [(48.8687, 2.3673), (48.8687, 2.3674), (48.8705, 2.3664)]
# -----------
# (48.8704561, 2.3663507) (48.8715703, 2.3635654)
# best [(48.8705, 2.3664), (48.8704, 2.3663), (48.871, 2.3659), (48.8708, 2.3655), (48.8716, 2.3636)]
# -----------
# (48.8715703, 2.3635654) (48.8675036, 2.355827)
# best [(48.8716, 2.3636), (48.8715, 2.3636), (48.8711, 2.3628), (48.8714, 2.3621), (48.8685, 2.3599), (48.8688, 2.356), (48.8689, 2.3557), (48.8675, 2.3558)]
# -----------
# (48.8675036, 2.355827) (48.8646241, 2.3640156)
# best [(48.8675, 2.3558), (48.8671, 2.3577), (48.8662, 2.3571), (48.866, 2.358), (48.8654, 2.3603), (48.8659, 2.3609), (48.8646, 2.364)]
# -----------
# (48.8646241, 2.3640156) (48.8627724, 2.3610521)
# best [(48.8646, 2.364), (48.8645, 2.3636), (48.8638, 2.3628), (48.8631, 2.362), (48.8628, 2.3611)]
# -----------
# (48.8627724, 2.3610521) (48.8647062, 2.3597995)
# best [(48.8628, 2.3611), (48.8628, 2.361), (48.8647, 2.3598)]
# -----------
# (48.8647062, 2.3597995) (48.868106, 2.3636766)
# best [(48.8647, 2.3598), (48.8672, 2.3633), (48.8671, 2.3636), (48.8676, 2.3633), (48.8675, 2.3636), (48.8676, 2.3637), (48.8681, 2.3637)]
# -----------
# (48.868106, 2.3636766) (48.8715027, 2.3603436)
# best [(48.8681, 2.3637), (48.8681, 2.3635), (48.8679, 2.3633), (48.8682, 2.3628), (48.8685, 2.3632), (48.8704, 2.3616), (48.8715, 2.3603)]
# -----------
# (48.8715027, 2.3603436) (48.8731067, 2.3614285)
# best [(48.8715, 2.3603), (48.8731, 2.3614)]
# -----------
# (48.8731067, 2.3614285) (48.8684079, 2.3662262)
# best [(48.8731, 2.3614), (48.8726, 2.3611), (48.8719, 2.3626), (48.8715, 2.3622), (48.8684, 2.3662)]
# -----------
# (48.8684079, 2.3662262) (48.8646241, 2.3640156)
# best [(48.8684, 2.3662), (48.8677, 2.3644), (48.8671, 2.3653), (48.8664, 2.3646), (48.8652, 2.3653), (48.8646, 2.364)]
# -----------
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c0f1eb093b2be9176232971e264ed8c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c0f1eb093b2be9176232971e264ed8c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5c0f1eb093b2be9176232971e264ed8c = L.map(
#                 &quot;map_5c0f1eb093b2be9176232971e264ed8c&quot;,
#                 {
#                     center: [48.8675, 2.3638],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f4d929efbfdf8fa4f7eee27d847be9f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3f4d929efbfdf8fa4f7eee27d847be9f.addTo(map_5c0f1eb093b2be9176232971e264ed8c);
#
#
#             var marker_eee94a6887392e67b4b8fba533904450 = L.marker(
#                 [48.8646, 2.364],
#                 {}
#             ).addTo(map_5c0f1eb093b2be9176232971e264ed8c);
#
#
#             var icon_e5588cbb55df29659577afeb113f6dea = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_eee94a6887392e67b4b8fba533904450.setIcon(icon_e5588cbb55df29659577afeb113f6dea);
#
#
#         var popup_c458117828e9e171f294852e5c940f5d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bfb246577f7696450d6fa5bcad790b30 = $(`&lt;div id=&quot;html_bfb246577f7696450d6fa5bcad790b30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0&lt;/div&gt;`)[0];
#                 popup_c458117828e9e171f294852e5c940f5d.setContent(html_bfb246577f7696450d6fa5bcad790b30);
#
#
#
#         marker_eee94a6887392e67b4b8fba533904450.bindPopup(popup_c458117828e9e171f294852e5c940f5d)
#         ;
#
#
#
#
#             var marker_68795c9b213c90db45789698fe491cf3 = L.marker(
#                 [48.8647, 2.3645],
#                 {}
#             ).addTo(map_5c0f1eb093b2be9176232971e264ed8c);
#
#
#             var icon_c8ab1787ab2aca197f3e77034ee1f13c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_68795c9b213c90db45789698fe491cf3.setIcon(icon_c8ab1787ab2aca197f3e77034ee1f13c);
#
#
#         var popup_70b90c9f973e2f6fbbae870a9eb156f2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_19912710402b89a5236754c9c54e9812 = $(`&lt;div id=&quot;html_19912710402b89a5236754c9c54e9812&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#                 popup_70b90c9f973e2f6fbbae870a9eb156f2.setContent(html_19912710402b89a5236754c9c54e9812);
#
#
#
#         marker_68795c9b213c90db45789698fe491cf3.bindPopup(popup_70b90c9f973e2f6fbbae870a9eb156f2)
#         ;
#
#
#
#
#             var marker_c94b4b9fd893325ca8b6f1e96d2bb725 = L.marker(
#                 [48.8652, 2.3653],
#                 {}
#             ).addTo(map_5c0f1eb093b2be9176232971e264ed8c);
#
#
#             var icon_3fbcdec728780adcd505335236f1b34e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c94b4b9fd893325ca8b6f1e96d2bb725.setIcon(icon_3fbcdec728780adcd505335236f1b34e);
#
#
#         var popup_d151a38ae8503946d0827f3394ee1205 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4402280f811199e67c0e8d835b0df417 = $(`&lt;div id=&quot;html_4402280f811199e67c0e8d835b0df417&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2&lt;/div&gt;`)[0];
#                 popup_d151a38ae8503946d0827f3394ee1205.setContent(html_4402280f811199e67c0e8d835b0df417);
#
#
#
#         marker_c94b4b9fd893325ca8b6f1e96d2bb725.bindPopup(popup_d151a38ae8503946d0827f3394ee1205)
#         ;
#
#
#
#
#             var marker_fa1ac0ae634a949b699d799728261160 = L.marker(
#                 [48.8645, 2.3661],
#                 {}
#             ).addTo(map_5c0f1eb093b2be9176232971e264ed8c);
#
#
#             var icon_0b4e08fc28d400fa5a75821fdbb3d699 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyp

# %%
plot_compare_polygons(final_contour, bicycle_contour)

# %%
from stravart.metrics import *

#Area of the difference between each segment and directions for the segment
diff_area(actual_bicycle_contour, path_mapping)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from stravart.metrics import *
#       3 #Area of the difference between each segment and directions for the segment
#       4 diff_area(actual_bicycle_contour, path_mapping)
#
# File ~/Desktop/Repos/stravart/stravart/metrics.py:2
#       1 import numpy as np
# ----> 2 import cv2
#       3 from scipy.spatial.distance import directed_hausdorff
#       4 from sklearn.preprocessing import MinMaxScaler
#
# ModuleNotFoundError: No module named 'cv2'

# %% [markdown]
# ## Operations

# %%
from stravart.operations import *

normed_poly = poly.scale_coordinates()
distortion = RadialDistortion(distortion_factor=0.3).apply(normed_poly)

plot_contours(normed_poly, distortion)

# %%
rotation = Rotation(angle=20).apply(normed_poly)
plot_contours(normed_poly, rotation)
